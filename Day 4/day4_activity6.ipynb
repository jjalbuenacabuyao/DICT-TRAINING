# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %%
my_data = pd.read_csv("C:\\Users\\User\\Documents\\DICT TRAINING - JOEL J. CABUYAO\\Demographic-Data.csv")

# %%
my_data
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
my_data.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
df = pd.DataFrame(my_data)
df.plot.scatter(x="Birth rate", y="Internet users")
plt.show()

# %%
sns.set_theme(style="darkgrid")
visual1 = sns.distplot(my_data["Internet users"])

# %%
visual2 = sns.boxplot(data=my_data, x="Income Group", y="Internet users")

# %%
sns.relplot(
    data=my_data, kind="line",
    x="Birth rate", y="Internet users"
)

# %%
sns.jointplot(data=my_data, x="Income Group", y="Birth rate")

# %%
sns.relplot(
    data=my_data,
    x="Birth rate", y="Internet users",
)

# %%
sns.histplot(my_data["Birth rate"])
# Out:
# <AxesSubplot:xlabel='Birth rate', ylabel='Count'>
